# %%
from tensorflow.keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = (x_train / 255).astype(float)
x_test = (x_test / 255).astype(float)

# %%
from hopfieldnn import hopfield_train

print(hopfield_train(x_train, y_train, 10))
print(hopfield_train(x_test, y_test, 10))
# Out:
# 0.4200333333333333
# 0.3344

# %%
from feedforwardnn import feedforward_train

feedforward_train(x_train, y_train, x_test, y_test, 10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 31s 16ms/step - loss: 0.3275 - accuracy: 0.8990 - val_loss: 0.2464 - val_accuracy: 0.9301
# Epoch 2/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.1805 - accuracy: 0.9435 - val_loss: 0.1909 - val_accuracy: 0.9415
# Epoch 3/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.1466 - accuracy: 0.9540 - val_loss: 0.2304 - val_accuracy: 0.9270
# Epoch 4/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.1291 - accuracy: 0.9607 - val_loss: 0.2693 - val_accuracy: 0.9206
# Epoch 5/10
# 1875/1875 [==============================] - 27s 15ms/step - loss: 0.1186 - accuracy: 0.9621 - val_loss: 0.3746 - val_accuracy: 0.8999
# Epoch 6/10
# 1875/1875 [==============================] - 28s 15ms/step - loss: 0.1051 - accuracy: 0.9671 - val_loss: 0.3891 - val_accuracy: 0.9026
# Epoch 7/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0959 - accuracy: 0.9697 - val_loss: 0.6067 - val_accuracy: 0.8619
# Epoch 8/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0926 - accuracy: 0.9705 - val_loss: 0.7551 - val_accuracy: 0.8454
# Epoch 9/10
# 1875/1875 [==============================] - 26s 14ms/step - loss: 0.0831 - accuracy: 0.9742 - val_loss: 0.8533 - val_accuracy: 0.8358
# Epoch 10/10
# 1875/1875 [==============================] - 27s 14ms/step - loss: 0.0788 - accuracy: 0.9751 - val_loss: 0.9933 - val_accuracy: 0.8273
# 313/313 [==============================] - 1s 4ms/step
# 0.9415

# %%
print("sdf")
# Out:
# sdf
